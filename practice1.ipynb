# %%
import csv
import string
from collections import defaultdict
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
nltk.download('stopwords')


# Function to read the CSV file and preprocess the data
def read_csv_and_preprocess(file_path):
    data = defaultdict(dict)

    # Define punctuation and stopwords
    punctuations = set(string.punctuation)
    stop_words = set(stopwords.words('english'))

    # Read CSV file
    with open(file_path, newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            article_id = int(row['ARTICLE_ID'])
            section_text = row['SECTION_TEXT']

            # Tokenize and preprocess section text
            tokens = word_tokenize(section_text.lower())
            filtered_tokens = [token for token in tokens if token not in stop_words and token not in punctuations]

            # Store preprocessed data in dictionary
            data[article_id] = filtered_tokens

    return data

# Example usage
csv_file_path = 'sampled.csv'
preprocessed_data = read_csv_and_preprocess(csv_file_path)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\bilal\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\bilal\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Function to calculate word count and word frequency for each article
def calculate_word_stats(data):
    word_stats = defaultdict(dict)

    for article_id, tokens in data.items():
        word_count = len(tokens)
        word_frequency = defaultdict(int)
        for word in tokens:
            word_frequency[word] += 1
        word_stats[article_id] = {'word_count': word_count, 'word_frequency': word_frequency}


    return word_stats

# Example usage
word_stats = calculate_word_stats(preprocessed_data)
word_stats
# Out:
# defaultdict(dict,
#             {55627: {'word_count': 23,
#               'word_frequency': defaultdict(int,
#                           {'delavan': 3,
#                            'founded': 1,
#                            'group': 1,
#                            'settlers': 1,
#                            'new': 2,
#                            'england': 1,
#                            'city': 1,
#                            'derives': 1,
#                            'name': 1,
#                            'edward': 1,
#                            'c.': 1,
#                            'temperance': 1,
#                            'advocate': 1,
#                            'albany': 1,
#                            'york': 1,
#                            'post': 1,
#                            'office': 1,
#                            'operation': 1,
#                            'since': 1,
#                            '1840': 1})},
#              63340: {'word_count': 28,
#               'word_frequency': defaultdict(int,
#                           {"''": 2,
#                            "'silver": 1,
#                            'creek': 2,
#                            'township': 4,
#                            'lake': 1,
#                            'county': 1,
#                            'minnesota': 2,
#                            'united': 1,
#                            'states': 1,
#                            'population': 1,
#                            '1178': 1,
#                            '2000': 1,
#                            'census': 1,
#                            'state': 1,
#                            'highway': 1,
#                            '61': 1,
#                            'serves': 1,
#                            'main': 1,
#                            'route': 1,
#                            'silver': 1,
#                            'organized': 1,
#                            '1905': 1})},
#              69485: {'word_count': 0, 'word_frequency': defaultdict(int, {})},
#              84731: {'word_count': 10,
#               'word_frequency': defaultdict(int,
#                           {'``': 1,
#                            'violent': 1,
#                            'femmes': 1,
#                            "''": 1,
#                            'adobe': 1,
#                            'flash': 1,
#                            'radio3net': 1,
#                            'streamed': 1,
#                            'copy': 1,
#                            'licensed': 1})},
#              98327: {'word_count': 78,
#               'word_frequency': defaultdict(int,
#                           {'town': 1,
#                            'kragerø': 3,
#                            'established': 1,
#                            'municipality': 4,
#                            '1': 2,
#                            'january': 2,
#                            '1838': 1,
#                            'see': 1,
#                            'formannskapsdistrikt': 1,
#                            'days': 1,
#                            'sailing': 1,
#                            'ships': 1,
#                            'one': 2,
#                            'norway': 2,
#                            "'s": 1,
#                            'largest': 1,
#                            'port': 1,
#                            'cities': 1,
#                            'rural': 1,
#                            'municipalities': 1,
#                            'sannidal': 1,
#                            'skåtøy': 1,
#                            'merged': 1,
#                            '1960.': 1,
#                            'includes': 1,
#                            '495': 1,
#                            'islands': 1,
#                            'islets': 1,
#                            'skerries': 1,
#                            'along': 1,
#                            '4000': 1,
#                            'leisure': 1,
#                            'houses': 1,
#                            'also': 1,
#                            '190': 1,
#                            'freshwater': 1,
#                            'lakes': 1,
#                            '===1694': 1,
#                            'murder===': 1,
#                            '17': 1,
#                            'august': 1,
#                            '1694': 1,
#                            'christian': 1,
#                            'hansen': 1,
#                            'ernst': 1,
#                            'killed': 1,
#                            'present-day': 1,
#                            '``': 2,
#                            'knivstikkersmauet': 1,
#                            "''": 2,
#                            'knife': 1,
#                            'stabber': 1,
#                            'alley': 1,
#                            'employee': 1,
#                            'postal': 1,
#                            'service': 1,
#                            'former': 1,
#                            'servant': 1,
#                            'ulrik': 1,
#                            'fredrik': 1,
#                            'gyldenløve': 1,
#                            'africans': 1,
#                            'time': 1,
#                            'living': 1,
#                            'whose': 1,
#                            'identity': 1,
#                            'known': 1})},
#              117812: {'word_count': 40,
#               'word_frequency': defaultdict(int,
#                           {'adult': 1,
#                            'human': 1,
#                            'brainstem': 1,
#                            'emerges': 1,
#                            'two': 2,
#                            'three': 2,
#                            'primary': 3,
#                            'vesicles': 3,
#                            'formed': 1,
#                            'neural': 1,
#                            'tube': 1,
#                            'mesencephalon': 1,
#                            'second': 1,
#                            'differentiate': 2,
#                            'secondary': 2,
#                            'vesicle': 2,
#                            'become': 3,
#                            'midbrain': 1,
#                            'third': 1,
#                            'rhombencephalon': 1,
#                            'hindbrain': 1,
#                            'metencephalon': 2,
#                            'myelencephalon': 2,
#                            'cerebellum': 1,
#                            'pons': 1,
#                            'caudal': 1,
#                            'medulla': 1})},
#              130726: {'word_count': 92,
#               'word_frequency': defaultdict(int,
#                           {'byng': 4,
#                            'born': 1,
#                            'family': 2,
#                            'seat': 1,
#                            'wrotham': 1,
#                            'park': 1,
#                            'hertfordshire': 1,
#                            'seventh': 1,
#                            'son': 1,
#                            '13th': 1,
#                            'youngest': 1,
#                            'child': 1,
#                            'earl': 1,
#                            'strafford': 1,
#                            'due': 1,
#                            'size': 1,
#                            'ran': 1,
#                            'relatively': 1,
#                            'frugal': 1,
#                            'household': 1,
#                            'harriet': 1,
#                            'elizabeth': 1,
#                            'cavendish': 1,
#                            'daughter': 1,
#                            'lord': 1,
#                            'chesham': 1,
#                            'age': 1,
#                            '17': 1,
#                            'enrolled': 1,
#                            'eton': 2,
#                            'college': 2,
#                            'although': 1,
#                            'enter': 1,
#                            'sixth': 1,
#                            'form': 1,
#                            'first': 1,
#                            'received': 2,
#                            'nickname': 1,
#                            '``': 4,
#                            'bungo': 1,
#                            "''": 4,
#                            '—to': 1,
#                            'distinguish': 1,
#                            'elder': 1,
#                            'brothers': 1,
#                            'byngo': 1,
#                            'bango': 1,
#                            '—but': 1,
#                            'time': 1,
#                            'undistinguished': 2,
#                            'poor': 1,
#                            'reports': 1,
#                            'indicative': 1,
#                            'attitude': 1,
#                            'towards': 1,
#                            'academics': 1,
#                            'traded': 1,
#                            'latin': 1,
#                            'grammar': 1,
#                            'book': 1,
#                            'brother': 1,
#                            'lionel': 1,
#                            "'s": 2,
#                            'best': 1,
#                            'trousers': 1,
#                            'hawker': 1,
#                            'pair': 1,
#                            'ferrets': 1,
#                            'pineapple': 1,
#                            'later': 1,
#                            'claimed': 1,
#                            'school': 1,
#                            'worst': 1,
#                            'scug': 1,
#                            'colloquial': 1,
#                            'term': 1,
#                            'boy': 1})},
#              140586: {'word_count': 16,
#               'word_frequency': defaultdict(int,
#                           {'avn': 1,
#                            '``': 1,
#                            'gina': 2,
#                            'lynn': 2,
#                            'hurt': 1,
#                            'motorcycle': 1,
#                            'stunt': 1,
#                            "''": 1,
#                            'dan': 1,
#                            'miller': 1,
#                            'august': 1,
#                            '29': 1,
#                            '2005': 1,
#                            'babepedia': 1})},
#              162554: {'word_count': 61,
#               'word_frequency': defaultdict(int,
#                           {'26': 1,
#                            'august': 1,
#                            '1625': 1,
#                            '``': 1,
#                            'tartu': 1,
#                            'capitulated': 1,
#                            'sweden': 1,
#                            "''": 1,
#                            '1627–1634': 1,
#                            'kasper': 1,
#                            'doenhoff': 1,
#                            'caspar': 1,
#                            'dönhoff': 1,
#                            'c.': 3,
#                            '1588–1645': 1,
#                            '1634–1640': 1,
#                            'gothard': 1,
#                            'jan': 1,
#                            'tyzenhauz': 1,
#                            'died': 3,
#                            '1640': 1,
#                            '1641–1651': 1,
#                            'andrzej': 1,
#                            'leszczyński': 3,
#                            '1606–1651': 1,
#                            '1651–1651': 1,
#                            'enoch': 1,
#                            'kolenda': 1,
#                            '1651–1654': 1,
#                            'teodor': 1,
#                            'denhoff': 1,
#                            '1654': 2,
#                            'pl': 1,
#                            '1654–1654': 1,
#                            'zygmunt': 2,
#                            'opacki': 2,
#                            '1654–1658': 1,
#                            'olbracht': 1,
#                            '1621–1680': 1,
#                            '–1657': 1,
#                            'aleksander': 1,
#                            'ludwik': 1,
#                            'wolff': 1,
#                            '1657–1658': 1,
#                            'wybranowski': 1,
#                            '1658–1660': 1,
#                            'przecław': 1,
#                            'paweł': 1,
#                            '1605–1670': 1,
#                            '1670–1676': 1,
#                            'samuel': 1,
#                            '1637–1676': 1})},
#              215054: {'word_count': 397,
#               'word_frequency': defaultdict(int,
#                           {'helm': 1,
#                            'station': 1,
#                            'aboard': 1,
#                            'western': 4,
#                            'australian': 4,
#                            'maritime': 4,
#                            'museum': 13,
#                            '2006': 1,
#                            'least': 1,
#                            'fourteen': 1,
#                            '``': 24,
#                            'oberon': 11,
#                            "''": 24,
#                            'confirmed': 1,
#                            'survived': 1,
#                            'form': 1,
#                            'seven': 1,
#                            'preserved': 6,
#                            'converted': 3,
#                            'vessels': 1,
#                            'tourist': 1,
#                            'attractions': 1,
#                            'two': 4,
#                            'partially': 2,
#                            'monuments': 1,
#                            'another': 2,
#                            'five': 1,
#                            'awaiting': 3,
#                            'conversion': 2,
#                            'work': 1,
#                            'otherwise': 1,
#                            'disposal': 1,
#                            'ex-royal': 1,
#                            'navy': 5,
#                            'submarines': 6,
#                            'uk': 1,
#                            'one': 2,
#                            'remains': 1,
#                            'hms': 1,
#                            'onyx': 1,
#                            'moved': 2,
#                            'barrow-in-furness': 1,
#                            'birkenhead': 1,
#                            'merseyside': 1,
#                            'closed': 1,
#                            'later': 2,
#                            'towed': 3,
#                            'gareloch': 1,
#                            'scotland': 1,
#                            'broken': 1,
#                            'scrap': 1,
#                            '2014': 1,
#                            'failed': 1,
#                            'attempts': 1,
#                            'turn': 1,
#                            'boat': 1,
#                            'located': 4,
#                            'chatham': 1,
#                            'harboured': 1,
#                            'sassnitz': 1,
#                            'germany': 1,
#                            'island': 2,
#                            'rügen': 1,
#                            'visited': 1,
#                            'british': 2,
#                            'transferred': 1,
#                            'canada': 2,
#                            'non-commissioned': 1,
#                            'training': 1,
#                            'vessel': 3,
#                            'spare': 1,
#                            'parts': 2,
#                            'disposed': 1,
#                            'australia': 3,
#                            "'s": 3,
#                            'six': 2,
#                            'display': 1,
#                            'either': 1,
#                            'completely': 1,
#                            'fremantle': 1,
#                            'national': 1,
#                            'darling': 1,
#                            'harbour': 2,
#                            'sydney': 1,
#                            'fin': 3,
#                            'outer': 1,
#                            'hull': 1,
#                            'stern': 1,
#                            'section': 1,
#                            'land': 1,
#                            'holbrook': 1,
#                            'new': 2,
#                            'south': 1,
#                            'wales': 1,
#                            'crib': 1,
#                            'point': 3,
#                            'westernport': 1,
#                            'bay': 1,
#                            'victoria': 2,
#                            'since': 1,
#                            '2002': 1,
#                            'lack': 1,
#                            'funding': 1,
#                            'cooperation': 1,
#                            'local': 1,
#                            'state': 1,
#                            'governments': 1,
#                            'means': 1,
#                            'volunteer': 1,
#                            'group': 1,
#                            'hoping': 1,
#                            'preserve': 1,
#                            'otama': 1,
#                            'attempted': 1,
#                            'sell': 1,
#                            'submarine': 4,
#                            'ebay': 1,
#                            'avail': 1,
#                            'stands': 2,
#                            'permanent': 2,
#                            'memorial': 3,
#                            'garden': 1,
#                            'rockingham': 1,
#                            'naval': 2,
#                            'park': 1,
#                            'three': 1,
#                            '-class': 3,
#                            'laid': 1,
#                            'halifax': 2,
#                            '2005': 1,
#                            'announced': 1,
#                            'four': 1,
#                            'surviving': 2,
#                            'canadian': 2,
#                            'minus': 1,
#                            'osiris': 1,
#                            'scrapped': 1,
#                            '1992': 1,
#                            'stripped': 1,
#                            'sold': 3,
#                            'scrapping': 1,
#                            'deteriorated': 1,
#                            'beyond': 1,
#                            'use': 2,
#                            'purchased': 1,
#                            'c': 1,
#                            '4': 1,
#                            'plus': 1,
#                            'tax': 1,
#                            'site': 1,
#                            'historique': 1,
#                            'de': 3,
#                            'la': 1,
#                            'pointe-au-père': 2,
#                            'quebec': 1,
#                            'july': 3,
#                            '2008.': 1,
#                            '2011': 1,
#                            'olympus': 1,
#                            'scrapyard': 2,
#                            'port': 2,
#                            'maitland': 1,
#                            'ontario': 2,
#                            'delivered': 1,
#                            'august': 1,
#                            '2011.': 1,
#                            'part': 1,
#                            'elgin': 1,
#                            'military': 1,
#                            'burwell': 1,
#                            'november': 1,
#                            '2012': 1,
#                            'become': 1,
#                            'focal': 1,
#                            'history': 1,
#                            'ojibwa': 1,
#                            'opened': 1,
#                            'public': 2,
#                            'tours': 1,
#                            '2013.': 1,
#                            'brazilian': 4,
#                            'tonelero': 1,
#                            'sank': 1,
#                            'docked': 1,
#                            'yards': 1,
#                            'praça': 1,
#                            'mauá': 1,
#                            'rio': 2,
#                            'janeiro': 2,
#                            '24': 1,
#                            'december': 1,
#                            '2000.': 1,
#                            'riachuelo': 1,
#                            'cultural': 2,
#                            'center': 1,
#                            'espaço': 1,
#                            'da': 1,
#                            'marinha': 1,
#                            'brasileira': 1,
#                            'chilean': 2,
#                            "o'brien": 1,
#                            'city': 2,
#                            'valdivia': 1,
#                            'first': 1,
#                            'chile': 1,
#                            'modified': 1,
#                            'asenav': 1,
#                            'shipyard': 1,
#                            'better': 1,
#                            'access': 1,
#                            'general': 1,
#                            'moored': 1,
#                            'calle-calle': 1,
#                            'river': 1,
#                            'cross': 1,
#                            '===successors===': 1,
#                            'class': 2,
#                            'briefly': 1,
#                            'succeeded': 1,
#                            'rn': 1,
#                            'service': 2,
#                            'upholder': 2,
#                            'upgraded': 1,
#                            'royal': 1,
#                            'refit': 1,
#                            'replacing': 1,
#                            'replaced': 3,
#                            's.': 1,
#                            "o'higgins": 1,
#                            'carrera': 1,
#                            'type': 1,
#                            '209': 1})},
#              249055: {'word_count': 142,
#               'word_frequency': defaultdict(int,
#                           {'throughout': 1,
#                            'career': 2,
#                            'norman': 5,
#                            'spent': 1,
#                            'much': 1,
#                            'time': 2,
#                            'giving': 1,
#                            'recitals': 2,
#                            'concerts': 1,
#                            'addition': 1,
#                            'operatic': 2,
#                            'given': 1,
#                            'regular': 1,
#                            'encompassing': 1,
#                            'classical': 1,
#                            'german': 1,
#                            'repertory': 1,
#                            'well': 1,
#                            'contemporary': 2,
#                            'masterpieces': 1,
#                            'schoenberg': 1,
#                            "'s": 1,
#                            '``': 5,
#                            'gurre-lieder': 1,
#                            "''": 5,
#                            'french': 1,
#                            'moderns': 1,
#                            'invariably': 1,
#                            'performed': 3,
#                            'original': 2,
#                            'tongue': 1,
#                            'combination': 1,
#                            'scholarship': 1,
#                            'artistry': 1,
#                            'contributed': 1,
#                            'consistently': 1,
#                            'successful': 1,
#                            'one': 2,
#                            'versatile': 1,
#                            'concert': 1,
#                            'singers': 2,
#                            'often': 1,
#                            'cited': 1,
#                            'innovative': 1,
#                            'programming': 1,
#                            'fervent': 1,
#                            'advocacy': 1,
#                            'music': 2,
#                            'earned': 1,
#                            'recognition': 1,
#                            'once-in-a-generation': 1,
#                            '’': 1,
#                            'simply': 1,
#                            'following': 1,
#                            'footsteps': 1,
#                            'others': 1,
#                            'staking': 1,
#                            'niche': 1,
#                            'history': 1,
#                            'singing': 1,
#                            'premiered': 1,
#                            'song': 2,
#                            'cycle': 1,
#                            'woman.life.song': 1,
#                            'composer': 1,
#                            'judith': 1,
#                            'weir': 1,
#                            'work': 1,
#                            'commissioned': 1,
#                            'carnegie': 2,
#                            'hall': 2,
#                            'texts': 1,
#                            'toni': 1,
#                            'morrison': 1,
#                            'maya': 1,
#                            'angelou': 1,
#                            'clarissa': 1,
#                            'pinkola': 1,
#                            'estés': 1,
#                            'selection': 1,
#                            'sacred': 1,
#                            'duke': 1,
#                            'ellington': 1,
#                            'recorded': 1,
#                            'jazz': 1,
#                            'album': 2,
#                            'jessye': 1,
#                            'sings': 1,
#                            'michel': 1,
#                            'legrand': 1,
#                            'soprano': 2,
#                            'co-lead': 1,
#                            'vangelis': 1,
#                            'project': 1,
#                            'mythodea': 1,
#                            'moscow': 1,
#                            'songs': 1,
#                            'mussorgsky': 1,
#                            'russian': 1,
#                            'projects': 1,
#                            'included': 1,
#                            '1984': 1,
#                            'heart': 1,
#                            'contains': 1,
#                            'numbers': 1,
#                            'films': 1,
#                            'musical': 1,
#                            'comedies': 1,
#                            '1990': 1,
#                            'performance': 1,
#                            'american': 1,
#                            'spirituals': 1,
#                            'kathleen': 1,
#                            'battle': 1})},
#              251652: {'word_count': 46,
#               'word_frequency': defaultdict(int,
#                           {'khmelnytskyi': 6,
#                            'railway': 2,
#                            'station': 1,
#                            'infrastructure': 1,
#                            'transportation': 1,
#                            'connections': 1,
#                            'moscow': 1,
#                            'prague': 1,
#                            'bratislava': 1,
#                            'warsaw': 1,
#                            'budapest': 1,
#                            'belgrade': 1,
#                            'major': 1,
#                            'ukrainian': 1,
#                            'cities': 1,
#                            'distance': 1,
#                            'kiev': 1,
#                            'estimated': 2,
#                            'highway': 1,
#                            'highways': 1,
#                            'kiev-lviv': 1,
#                            'odessa-lviv': 1,
#                            'chernivtsi-kiev': 1,
#                            'pass': 1,
#                            'city': 1,
#                            'served': 1,
#                            'ruzhychna': 1,
#                            'airport': 3,
#                            "'s": 1,
#                            'concrete': 1,
#                            'runway': 1,
#                            'check': 1,
#                            'point': 1,
#                            'crossing': 1,
#                            'state': 1,
#                            'border': 1,
#                            'ukraine': 1})},
#              270848: {'word_count': 28,
#               'word_frequency': defaultdict(int,
#                           {"''": 2,
#                            "'pavel": 1,
#                            'kubina': 1,
#                            'born': 1,
#                            'april': 1,
#                            '15': 1,
#                            '1977': 1,
#                            'czech': 1,
#                            'former': 1,
#                            'ice': 1,
#                            'hockey': 2,
#                            'defenceman': 1,
#                            'played': 1,
#                            'national': 1,
#                            'league': 1,
#                            'nhl': 1,
#                            'tampa': 1,
#                            'bay': 1,
#                            'lightning': 1,
#                            'toronto': 1,
#                            'maple': 1,
#                            'leafs': 1,
#                            'atlanta': 1,
#                            'thrashers': 1,
#                            'philadelphia': 1,
#                            'flyers': 1})},
#              279986: {'word_count': 102,
#               'word_frequency': defaultdict(int,
#                           {'prior': 1,
#                            'mid-1800s': 1,
#                            'development': 1,
#                            'electronics': 1,
#                            'necessary': 1,
#                            'mathematics': 1,
#                            'see': 1,
#                            'euler': 1,
#                            'material': 1,
#                            'science': 1,
#                            'fully': 1,
#                            'understand': 1,
#                            'pressure': 5,
#                            'vessel': 1,
#                            'design': 1,
#                            'internal': 1,
#                            'ballistics': 1,
#                            'lot': 1,
#                            'detailed': 1,
#                            'objective': 1,
#                            'information': 1,
#                            'barrels': 2,
#                            'actions': 1,
#                            'would': 1,
#                            'simply': 1,
#                            'built': 1,
#                            'strong': 1,
#                            'enough': 1,
#                            'survive': 1,
#                            'known': 1,
#                            'overload': 1,
#                            'proof': 1,
#                            'test': 2,
#                            'muzzle': 1,
#                            'velocity': 1,
#                            'change': 1,
#                            'could': 2,
#                            'surmised': 1,
#                            'distance': 1,
#                            'projectile': 2,
#                            'traveled': 1,
#                            '1800s': 1,
#                            'began': 1,
#                            'instrumented': 2,
#                            'holes': 1,
#                            'drilled': 2,
#                            'barrel': 3,
#                            '``': 1,
#                            'crusher': 1,
#                            'gauges': 2,
#                            "''": 1,
#                            'using': 2,
#                            'copper': 2,
#                            'pellets': 1,
#                            'attached': 1,
#                            'gun': 1,
#                            'fired': 1,
#                            'measured': 2,
#                            'indirectly': 1,
#                            'much': 1,
#                            'pellet': 1,
#                            'deformed': 1,
#                            'measurement': 1,
#                            'indicated': 1,
#                            'maximum': 1,
#                            'reached': 1,
#                            'point': 1,
#                            '1960s': 1,
#                            'piezoelectric': 1,
#                            'strain': 1,
#                            'used': 1,
#                            'allow': 1,
#                            'instantaneous': 1,
#                            'pressures': 1,
#                            'need': 1,
#                            'port': 1,
#                            'recently': 1,
#                            'advanced': 1,
#                            'telemetry': 1,
#                            'acceleration-hardened': 1,
#                            'sensors': 1,
#                            'projectiles': 1,
#                            'developed': 1,
#                            'measure': 1,
#                            'base': 1,
#                            'acceleration': 1})},
#              299479: {'word_count': 124,
#               'word_frequency': defaultdict(int,
#                           {'``': 1,
#                            "'men": 1,
#                            "'s": 3,
#                            '200': 1,
#                            'metre': 1,
#                            'individual': 2,
#                            'medley': 2,
#                            "''": 1,
#                            'event': 1,
#                            '2004': 1,
#                            'olympic': 6,
#                            'games': 1,
#                            'contested': 1,
#                            'aquatic': 1,
#                            'centre': 1,
#                            'athens': 2,
#                            'sports': 1,
#                            'complex': 1,
#                            'greece': 1,
#                            'august': 1,
#                            '18': 1,
#                            '19.': 1,
#                            'u.s.': 1,
#                            'swimmer': 2,
#                            'michael': 1,
#                            'phelps': 3,
#                            'blasted': 1,
#                            'record': 4,
#                            '1:57.14': 1,
#                            'claim': 1,
#                            'fourth': 1,
#                            'career': 1,
#                            'gold': 1,
#                            'medal': 2,
#                            'swimming': 2,
#                            'coming': 1,
#                            'fifth': 2,
#                            'place': 1,
#                            'final': 2,
#                            'turn': 1,
#                            'teammate': 2,
#                            'ryan': 1,
#                            'lochte': 1,
#                            'powered': 1,
#                            'home': 1,
#                            'silver': 1,
#                            '1:58.78.': 1,
#                            'meanwhile': 1,
#                            'george': 1,
#                            'bovell': 1,
#                            'held': 1,
#                            'hungary': 1,
#                            'lászló': 1,
#                            'cseh': 1,
#                            'four': 2,
#                            'hundredths': 1,
#                            'second': 1,
#                            '0.04': 1,
#                            'give': 1,
#                            'trinidad': 1,
#                            'tobago': 1,
#                            'first': 1,
#                            'ever': 1,
#                            'commonwealth': 1,
#                            '1:58.80.': 1,
#                            'earlier': 2,
#                            'semifinals': 1,
#                            'posted': 1,
#                            'new': 1,
#                            '1:58.52': 1,
#                            'previously': 1,
#                            'set': 2,
#                            'italian': 1,
#                            'defending': 1,
#                            'champion': 1,
#                            'massimiliano': 1,
#                            'rosolino': 2,
#                            'sydney': 1,
#                            'years': 1,
#                            'along': 1,
#                            'alessio': 1,
#                            'boggiatto': 1,
#                            'failed': 1,
#                            'reach': 1,
#                            'top': 1,
#                            '8': 1,
#                            'tenth': 1,
#                            'eleventh-place': 1,
#                            'effort': 1,
#                            'tunisia': 1,
#                            'oussama': 1,
#                            'mellouli': 1,
#                            'placed': 1,
#                            '400': 1,
#                            'also': 1,
#                            'missed': 1,
#                            'cut': 1,
#                            'african': 1,
#                            '2:01.11': 1})},
#              335181: {'word_count': 65,
#               'word_frequency': defaultdict(int,
#                           {"''": 3,
#                            "'cucujiformia": 1,
#                            'infraorder': 2,
#                            'polyphagan': 1,
#                            'beetles': 13,
#                            'representing': 1,
#                            'vast': 1,
#                            'majority': 1,
#                            'plant-eating': 1,
#                            'contains': 1,
#                            'six': 1,
#                            'superfamilies': 1,
#                            'chrysomeloidea': 1,
#                            '~7': 1,
#                            'families': 4,
#                            'including': 3,
#                            'longhorn': 1,
#                            'leaf': 1,
#                            'cleroidea': 1,
#                            'checkered': 1,
#                            'bark-gnawing': 1,
#                            'soft-winged': 1,
#                            'flower': 1,
#                            'cucujoidea': 1,
#                            '32': 1,
#                            'includes': 1,
#                            'ladybirds': 1,
#                            'fungus': 1,
#                            'curculionoidea': 1,
#                            '~8': 1,
#                            'primarily': 1,
#                            'consisting': 1,
#                            'weevils': 1,
#                            'also': 1,
#                            'snout': 1,
#                            'bark': 1,
#                            'lymexyloidea': 1,
#                            'ship-timber': 1,
#                            'tenebrionoidea': 1,
#                            'formerly': 1,
#                            '``': 1,
#                            'heteromera': 1,
#                            '30': 1,
#                            'blister': 1,
#                            'ant-like': 1})},
#              335867: {'word_count': 37,
#               'word_frequency': defaultdict(int,
#                           {"''": 2,
#                            "'6l6": 1,
#                            'designator': 1,
#                            'vacuum': 1,
#                            'tube': 1,
#                            'introduced': 1,
#                            'radio': 1,
#                            'corporation': 1,
#                            'america': 1,
#                            'july': 1,
#                            '1936.': 1,
#                            'time': 1,
#                            'philips': 2,
#                            'already': 1,
#                            'developed': 1,
#                            'patented': 1,
#                            'power': 2,
#                            'pentode': 2,
#                            'designs': 1,
#                            'fast': 1,
#                            'replacing': 1,
#                            'triodes': 1,
#                            'due': 1,
#                            'greater': 1,
#                            'efficiency': 1,
#                            'beam': 1,
#                            'tetrode': 1,
#                            'design': 1,
#                            '6l6': 1,
#                            'allowed': 1,
#                            'rca': 1,
#                            'circumvent': 1,
#                            'patent': 1})},
#              358659: {'word_count': 17,
#               'word_frequency': defaultdict(int,
#                           {'geographical': 1,
#                            'features': 1,
#                            'include': 1,
#                            'anderson': 1,
#                            'heights': 1,
#                            'kosco': 1,
#                            'glacier': 3,
#                            'mcintyre': 1,
#                            'promontory': 1,
#                            'mincey': 1,
#                            'mount': 2,
#                            'boyd': 1,
#                            'cromie': 1,
#                            'ramsey': 1})},
#              385034: {'word_count': 7,
#               'word_frequency': defaultdict(int,
#                           {'laetare': 1,
#                            'sunday': 2,
#                            'advent': 1,
#                            'gaudete': 1,
#                            'christmas': 1,
#                            'carol': 1})},
#              386697: {'word_count': 405,
#               'word_frequency': defaultdict(int,
#                           {'===': 4,
#                            'formation': 1,
#                            '1991': 1,
#                            'video': 2,
#                            'game': 12,
#                            'developer': 1,
#                            'david': 1,
#                            'perry': 7,
#                            'working': 1,
#                            'probe': 1,
#                            'software': 1,
#                            'london': 1,
#                            'movie': 1,
#                            'license': 2,
#                            'based': 2,
#                            '``': 20,
#                            'terminator': 1,
#                            "''": 24,
#                            'mega': 2,
#                            'drive/genesis': 2,
#                            'published': 1,
#                            'virgin': 3,
#                            'games': 6,
#                            'irvine': 1,
#                            'california': 1,
#                            'proposal': 1,
#                            'made': 2,
#                            'agreed': 1,
#                            'complete': 1,
#                            'work': 2,
#                            'united': 1,
#                            'states': 2,
#                            'moved': 1,
#                            'join': 1,
#                            'usa': 2,
#                            'development': 3,
#                            'team': 2,
#                            'developed': 1,
#                            'mcdonald': 1,
#                            "'s": 8,
#                            'global': 1,
#                            'gladiators': 1,
#                            '7-up': 1,
#                            'cool': 1,
#                            'spot': 1,
#                            'early': 1,
#                            'disney': 2,
#                            'jungle': 1,
#                            'book': 1,
#                            'worked': 1,
#                            'aladdin': 1,
#                            'joint': 1,
#                            'venture': 1,
#                            'sega': 4,
#                            'america': 1,
#                            'commercial': 3,
#                            'successful': 4,
#                            'time': 1,
#                            'got': 1,
#                            'us': 1,
#                            'green': 1,
#                            'card': 1,
#                            'formed': 2,
#                            'new': 3,
#                            'company': 5,
#                            'fund': 1,
#                            'signed': 1,
#                            'three-game': 1,
#                            'distribution': 1,
#                            'deal': 1,
#                            'playmates': 2,
#                            'interactive': 2,
#                            'entertainment': 9,
#                            'shiny': 10,
#                            'inc.': 4,
#                            'october': 3,
#                            '1993.': 1,
#                            'first': 1,
#                            'release': 2,
#                            'earthworm': 5,
#                            'jim': 5,
#                            'commercially': 2,
#                            'year': 2,
#                            'award': 1,
#                            'several': 2,
#                            'merchandising': 1,
#                            'deals': 1,
#                            'followed': 2,
#                            'resulted': 1,
#                            'tv': 1,
#                            'show': 1,
#                            'comic': 1,
#                            'books': 1,
#                            'toy': 1,
#                            'lines': 1,
#                            'products': 1,
#                            'later': 1,
#                            'ported': 2,
#                            'platforms': 2,
#                            'sequel': 1,
#                            'titled': 1,
#                            '2': 2,
#                            '1995.': 1,
#                            'acquired': 2,
#                            'interplay': 3,
#                            'half': 1,
#                            'original': 1,
#                            'eight-man': 1,
#                            'including': 1,
#                            'right-hand': 1,
#                            'man': 1,
#                            'doug': 1,
#                            'tennapel': 1,
#                            'left': 2,
#                            'form': 3,
#                            'gaming': 2,
#                            'neverhood': 1,
#                            'nintendo': 1,
#                            'also': 1,
#                            'offers': 1,
#                            'acquire': 1,
#                            'turned': 1,
#                            'according': 1,
#                            "'ve": 1,
#                            'always': 1,
#                            'wanted': 1,
#                            'cover': 1,
#                            'whole': 1,
#                            'field': 1,
#                            '1997': 2,
#                            'former': 1,
#                            'employees': 1,
#                            'nick': 1,
#                            'bruty': 1,
#                            'president': 1,
#                            'bob': 1,
#                            'stevenson': 1,
#                            'ceo': 1,
#                            'planet': 1,
#                            'moon': 1,
#                            'studios': 2,
#                            'two': 3,
#                            'created': 2,
#                            'mdk': 2,
#                            '3d': 3,
#                            'action': 2,
#                            'one': 1,
#                            'precursors': 1,
#                            'third': 1,
#                            'person': 1,
#                            'shooter': 1,
#                            'genre': 1,
#                            'would': 1,
#                            'released': 3,
#                            'pc': 1,
#                            '1998.': 1,
#                            'co-published': 1,
#                            '2000': 1,
# ...
#                            'national': 1,
#                            'rural': 1,
#                            'fire': 2,
#                            'authority': 1,
#                            'customs': 1,
#                            'service': 2,
#                            'force': 1,
#                            'police': 1,
#                            'business': 1,
#                            'innovation': 1,
#                            'employment': 1,
#                            'participated': 1,
#                            '2013': 1,
#                            'purpose': 1,
#                            'developing': 1,
#                            'underground': 1,
#                            'mines': 1,
#                            'protocol': 1,
#                            '===wider': 1,
#                            'adoption===': 1,
#                            '====business': 1,
#                            'continuity/crisis': 1,
#                            'management====': 1,
#                            'recent': 1,
#                            'years': 1,
#                            'also': 1,
#                            'recognised': 2,
#                            'best': 1,
#                            'practice': 1,
#                            'implementing': 1,
#                            'structures': 1,
#                            'response': 2,
#                            'recovery': 1,
#                            'many': 1,
#                            'organisations': 1,
#                            'outside': 1,
#                            'identified': 1,
#                            'adopting': 2,
#                            'lifeline': 1,
#                            'utilities': 1,
#                            'universities': 1,
#                            'businesses': 1,
#                            'key': 1,
#                            'benefits': 1,
#                            'standard': 1,
#                            'able': 1,
#                            'interoperate': 1,
#                            'complex': 1,
#                            'events': 1,
#                            'involve': 1,
#                            'one': 1,
#                            'agency': 1,
#                            '====land': 1,
#                            'search': 2,
#                            'rescue====': 1,
#                            'land': 1,
#                            'rescue': 1,
#                            'inc': 1,
#                            'landsar': 1,
#                            'widely': 1,
#                            'adopted': 1,
#                            'use': 1})},
#              670370: {'word_count': 44,
#               'word_frequency': defaultdict(int,
#                           {"''": 2,
#                            "'darren": 1,
#                            'boyko': 1,
#                            'born': 1,
#                            'january': 1,
#                            '16': 1,
#                            '1964': 1,
#                            'winnipeg': 2,
#                            'manitoba': 1,
#                            'nhl': 2,
#                            'one-gamer': 2,
#                            'elitserien': 2,
#                            'played': 1,
#                            'one': 2,
#                            'game': 2,
#                            'jets': 1,
#                            '1989': 1,
#                            'västra': 1,
#                            'frölunda': 1,
#                            'hc': 1,
#                            '1997.': 1,
#                            'notable': 1,
#                            'numerous': 1,
#                            'years': 1,
#                            'hifk': 1,
#                            '2006': 1,
#                            'became': 1,
#                            'second': 1,
#                            'non-finnish': 1,
#                            'player': 1,
#                            'carl': 1,
#                            'brewer': 1,
#                            'inducted': 1,
#                            'finnish': 1,
#                            'hockey': 1,
#                            'hall': 1,
#                            'fame': 1})},
#              673618: {'word_count': 15,
#               'word_frequency': defaultdict(int,
#                           {'married': 1,
#                            'women': 1,
#                            'young': 1,
#                            'children': 1,
#                            'carers': 1,
#                            'claim': 2,
#                            'credits': 1,
#                            'ni': 1,
#                            'contributions': 1,
#                            'pensioners': 1,
#                            'low': 1,
#                            'incomes': 1,
#                            'pension': 1,
#                            'credit': 1})},
#              721852: {'word_count': 0, 'word_frequency': defaultdict(int, {})},
#              725063: {'word_count': 151,
#               'word_frequency': defaultdict(int,
#                           {"''": 3,
#                            "'daniel": 1,
#                            'nash': 6,
#                            '1763': 1,
#                            '–': 1,
#                            'june': 1,
#                            '4': 1,
#                            '1837': 1,
#                            'episcopal': 2,
#                            'priest': 2,
#                            'missionary': 2,
#                            'native': 1,
#                            'americans': 1,
#                            'european': 1,
#                            'settlers': 1,
#                            'frontier': 1,
#                            'central': 1,
#                            'new': 5,
#                            'york': 4,
#                            'born': 2,
#                            'great': 2,
#                            'barrington': 1,
#                            'massachusetts': 1,
#                            'graduated': 1,
#                            'yale': 1,
#                            'university': 1,
#                            'connecticut': 1,
#                            'became': 2,
#                            'teacher': 1,
#                            'studied': 1,
#                            'ordination': 1,
#                            'moved': 1,
#                            'lebanon': 1,
#                            '1790s': 1,
#                            'taught': 1,
#                            'school': 1,
#                            'lay': 1,
#                            'leader': 1,
#                            'church': 2,
#                            'met': 1,
#                            'wife': 1,
#                            'partner-to-be': 1,
#                            '``': 1,
#                            "'olive": 1,
#                            'lusk': 1,
#                            'ordained': 1,
#                            'october': 1,
#                            '11': 1,
#                            '1801.': 1,
#                            'nashes': 1,
#                            'including': 1,
#                            'child': 1,
#                            'move': 1,
#                            'newly': 1,
#                            'settled': 1,
#                            'regions': 1,
#                            'western': 1,
#                            'otsego': 1,
#                            'county': 1,
#                            'held': 1,
#                            'services': 1,
#                            'small': 1,
#                            'settlements': 1,
#                            'richfield': 1,
#                            'exeter': 1,
#                            'morris': 1,
#                            'father': 1,
#                            'performed': 2,
#                            'preaching': 1,
#                            'olive': 1,
#                            'led': 1,
#                            'singing': 1,
#                            'responses': 1,
#                            'also': 2,
#                            'preached': 1,
#                            'members': 1,
#                            'oneida': 1,
#                            'tribe': 1,
#                            '1804': 1,
#                            '1816': 1,
#                            '496': 1,
#                            'baptisms': 1,
#                            'organized': 1,
#                            '12': 1,
#                            'parishes': 1,
#                            'area': 1,
#                            '1800': 2,
#                            'presided': 1,
#                            'funeral': 1,
#                            'hannah': 1,
#                            'cooper': 2,
#                            'sister': 1,
#                            'james': 1,
#                            'fenimore': 1,
#                            'first': 1,
#                            'rector': 1,
#                            'christ': 1,
#                            'cooperstown': 1,
#                            'another': 1,
#                            'daniel': 1,
#                            'presbyterian': 1,
#                            'minister': 1,
#                            'early': 1,
#                            "'s": 1,
#                            'known': 1,
#                            'today': 1,
#                            'labored': 1,
#                            'prayer': 1,
#                            'second': 1,
#                            'awakening': 1,
#                            'relation': 1,
#                            'ministry': 1,
#                            'evangelist': 1,
#                            'charles': 1,
#                            'g.': 1,
#                            'finney': 1,
#                            'abington': 1,
#                            'mass': 1,
#                            'nov': 1,
#                            '27th': 1,
#                            '1775': 1,
#                            'died': 1,
#                            'december': 1,
#                            '20th': 1,
#                            '1831': 1,
#                            'verona': 1})},
#              756092: {'word_count': 29,
#               'word_frequency': defaultdict(int,
#                           {"''": 2,
#                            "'opt-in": 1,
#                            'email': 5,
#                            'term': 1,
#                            'used': 1,
#                            'someone': 1,
#                            'given': 1,
#                            'option': 1,
#                            'receive': 1,
#                            'typically': 1,
#                            'sort': 1,
#                            'mailing': 1,
#                            'list': 1,
#                            'newsletter': 1,
#                            'advertising': 1,
#                            'without': 1,
#                            'obtaining': 1,
#                            'permission': 1,
#                            'sending': 1,
#                            'unsolicited': 1,
#                            'bulk': 1,
#                            'better': 1,
#                            'known': 1,
#                            'spam': 1})},
#              765831: {'word_count': 0, 'word_frequency': defaultdict(int, {})},
#              779406: {'word_count': 90,
#               'word_frequency': defaultdict(int,
#                           {'commander': 1,
#                            'chief': 1,
#                            'general': 1,
#                            'army': 1,
#                            'all-forces': 1,
#                            'high': 1,
#                            'ranks': 3,
#                            'unique': 1,
#                            'feature': 1,
#                            'navy': 1,
#                            'use': 2,
#                            'three': 1,
#                            'lieutenant': 6,
#                            'frigate': 1,
#                            'corvette': 1,
#                            'ship-of-the-line': 1,
#                            'ensign': 2,
#                            'rank': 1,
#                            'naval': 1,
#                            'name': 1,
#                            'shoulder': 1,
#                            'insignia': 1,
#                            'admiral': 3,
#                            "''": 20,
#                            'almirante': 1,
#                            'vice': 1,
#                            'vicealmirante': 1,
#                            'rear': 1,
#                            'admiral/counter': 1,
#                            'contralmirante': 1,
#                            'captain/ship-of-the-line': 1,
#                            'captain': 3,
#                            'capitán': 3,
#                            'de': 6,
#                            'navío': 2,
#                            'commander/corvette': 1,
#                            'fragata': 2,
#                            'commander/frigate': 1,
#                            'corbeta': 2,
#                            'lieutenant/ship-of-the-line': 1,
#                            'teniente': 3,
#                            'junior': 1,
#                            'grade/frigate': 1,
#                            'probationary': 1,
#                            'lieutenant/corvette': 1,
#                            'alférez': 1})},
#              784736: {'word_count': 74,
#               'word_frequency': defaultdict(int,
#                           {'1975': 1,
#                            'derek': 1,
#                            'bailey': 1,
#                            'steve': 1,
#                            'beresford': 1,
#                            'max': 1,
#                            'boucher': 1,
#                            'paul': 2,
#                            'burwell': 2,
#                            'jack': 1,
#                            'cooke': 1,
#                            'peter': 1,
#                            'cusack': 1,
#                            'hugh': 1,
#                            'davies': 1,
#                            'madelaine': 2,
#                            'martin': 2,
#                            'davidson': 2,
#                            'richard': 1,
#                            'leigh': 1,
#                            'evan': 2,
#                            'parker': 2,
#                            'john': 1,
#                            'russell': 1,
#                            'david': 1,
#                            'toop': 1,
#                            'philipp': 1,
#                            'wachsmann': 1,
#                            'colin': 1,
#                            'wood': 1,
#                            'came': 1,
#                            'together': 1,
#                            'agreed': 1,
#                            'produce': 1,
#                            'magazine': 1,
#                            'would': 1,
#                            'independent': 1,
#                            'dedicated': 1,
#                            'mainly': 1,
#                            'coverage': 1,
#                            'free': 1,
#                            'improvised': 1,
#                            'music': 1,
#                            'need': 1,
#                            'originally': 1,
#                            'suggested': 1,
#                            'conversation': 1,
#                            'title': 2,
#                            'proposed': 1,
#                            'first': 1,
#                            'meeting': 1,
#                            'davidsons': 1,
#                            'house': 1,
#                            'unanimously': 1,
#                            'adopted': 1,
#                            'represented': 1,
#                            'paradigm': 1,
#                            'shift': 1,
#                            "''": 2,
#                            'musics': 1,
#                            'headquartered': 1,
#                            'london': 1,
#                            'published': 1,
#                            'since': 1,
#                            '1979': 1})}})

# %%
from collections import Counter

def perform_apriori_analysis(word_stats):
    # Perform apriori analysis here
    # Here, let's find the most frequent words across all articles
    
    # Combine word frequencies from all articles
    all_word_freq = Counter()
    for stats in word_stats.values():
        all_word_freq.update(stats['word_frequency'])
    
    # Find frequent words (e.g., those that appear in at least 3 articles)
    frequent_words = {word: freq for word, freq in all_word_freq.items() if freq >= 3}
    
    # Store results in a dictionary
    apriori_results = {
        'frequent_words': frequent_words
    }
    
    return apriori_results

# Example usage
apriori_results = perform_apriori_analysis(word_stats)
print("Apriori analysis results:")
print(apriori_results)
# Out:
# Apriori analysis results:
# {'frequent_words': {'delavan': 3, 'group': 3, 'new': 25, 'city': 5, 'c.': 4, 'york': 5, 'since': 4, "''": 114, 'township': 4, 'county': 3, 'united': 3, 'states': 3, 'state': 3, '``': 68, 'kragerø': 3, 'municipality': 4, '1': 3, 'january': 3, 'one': 14, "'s": 26, 'port': 4, 'along': 3, 'also': 10, 'august': 5, 'killed': 4, 'service': 7, 'former': 4, 'time': 7, 'known': 4, 'two': 12, 'three': 4, 'primary': 4, 'vesicles': 3, 'formed': 3, 'second': 5, 'become': 8, 'third': 3, 'byng': 4, 'born': 6, 'family': 6, 'son': 3, 'daughter': 3, 'enter': 3, 'form': 5, 'first': 10, 'received': 4, 'poor': 3, 'later': 5, 'died': 5, 'leszczyński': 3, 'western': 5, 'australian': 4, 'maritime': 5, 'museum': 13, '2006': 4, 'oberon': 11, 'survived': 3, 'preserved': 6, 'converted': 3, 'partially': 3, 'another': 5, 'awaiting': 3, 'work': 4, 'navy': 9, 'submarines': 6, 'moved': 5, 'towed': 3, 'located': 4, 'island': 3, 'british': 3, 'vessel': 4, 'australia': 3, 'six': 4, 'national': 3, 'fin': 3, 'south': 4, 'point': 5, 'bay': 4, 'submarine': 4, 'memorial': 3, 'naval': 4, '-class': 3, 'four': 3, 'sold': 4, 'use': 5, 'de': 9, 'july': 4, 'burwell': 3, 'november': 3, 'brazilian': 4, 'december': 3, 'better': 4, 'river': 6, 'replacing': 3, 'replaced': 3, 'career': 3, 'norman': 6, 'given': 3, 'well': 4, 'performed': 7, 'original': 4, 'successful': 5, 'music': 3, 'following': 3, 'hall': 3, 'battle': 9, 'khmelnytskyi': 6, 'railway': 4, 'airport': 3, 'hockey': 3, 'played': 3, 'league': 3, 'nhl': 3, 'development': 5, 'pressure': 6, 'would': 4, 'built': 4, 'barrel': 4, 'using': 4, 'used': 4, 'developed': 3, 'olympic': 6, 'games': 9, 'greece': 3, 'phelps': 3, 'record': 4, 'claim': 3, 'medal': 4, 'earlier': 4, 'years': 3, 'beetles': 13, 'families': 4, 'including': 7, 'america': 3, 'glacier': 3, '===': 6, 'game': 14, 'perry': 7, 'virgin': 3, 'made': 3, 'agreed': 3, 'team': 4, 'early': 3, 'sega': 4, 'commercial': 3, 'us': 5, 'company': 6, 'entertainment': 9, 'shiny': 10, 'inc.': 4, 'october': 5, 'earthworm': 5, 'jim': 5, 'year': 3, 'several': 3, 'interplay': 3, '3d': 3, 'action': 3, 'person': 3, 'released': 4, 'became': 8, 'matrix': 3, 'called': 3, 'may': 6, 'roosevelt': 3, 'callaghan': 8, 'command': 3, 'san': 3, 'francisco': 3, 'great': 4, 'captain': 5, 'many': 4, 'rear': 4, 'admiral': 8, 'staff': 3, 'commander': 5, 'area': 4, 'vice': 3, 'led': 3, 'fire': 3, 'lieutenant': 7, 'sea': 3, 'surgery': 5, 'lasek': 3, 'cornea': 3, 'epithelial': 4, 'layer': 3, 'sheet': 3, 'end': 3, 'kents': 5, 'bank': 5, 'road': 3, 'usually': 3, 'feature': 3, 'barral': 7, 'savoy': 6, 'helped': 3, 'provence': 3, 'charles': 5, 'fall': 6, 'season': 3, 'title': 3, 'cims': 4, 'emergency': 4, 'agencies': 4, 'management': 4, 'zealand': 8, 'defence': 3, 'ministry': 6, 'nash': 6, 'email': 5, 'ranks': 3, 'capitán': 3, 'teniente': 3}}

# %%
# Function to calculate Jaccard similarity between two sets
def jaccard_similarity(set1, set2):
    intersection = set1.intersection(set2)
    union = set1.union(set2)
    similarity = len(intersection) / len(union)
    return similarity

# Function to find relevant articles based on user query
def find_relevant_articles(query, word_stats):
    relevant_articles = []

    # Preprocess query
    query_tokens = word_tokenize(query.lower())
    query_set = set(query_tokens)

    # Iterate through word stats of each article
    for article_id, stats in word_stats.items():
        article_tokens = set(stats['word_frequency'].keys())
        similarity = jaccard_similarity(query_set, article_tokens)
        if similarity >= 0.5:
            relevant_articles.append(article_id)

    return relevant_articles

# Example usage
user_query = input("Enter your query: ")
relevant_articles = find_relevant_articles(user_query, word_stats)
print("Relevant articles based on the query:")
for article_id in relevant_articles:
    print(f"Article {article_id}")
# Out:
# Relevant articles based on the query:
